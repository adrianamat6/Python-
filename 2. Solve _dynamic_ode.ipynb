# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint

# %%
def tete(y,t,K,u):
    tau = 5.0
    dydt = (-y + K*u )/tau

    return dydt

# %%
# Parameters
K = 2.0
u = np.zeros(len(tspan))
u[3:] = 1.0 

# Integration between
tspan = np.linspace(0,10,11)

#Initial condition
y0 = 0



# Storage
ys = np.zeros(len(tspan))
ys[0] = y0

# Solve dynamic system
for i in range (len(tspan)-1):
    ts = [tspan[i],tspan[i+1]]
    y = odeint(tete, y0, ts, args=(K,u[i]))
    
    y0 = y[1]
    ys[i+1] = y0

    print(y[1])

    plt.figure()
    plt.plot(tspan,ys)
    plt.xlabel('Time')
    plt.ylabel('y')
# Out:
# [0.]
# [0.]
# [0.]
# [0.36253849]
# [0.65935989]
# [0.90237668]
# [1.101342]
# [1.26424102]
# [1.39761146]
# [1.50680593]
